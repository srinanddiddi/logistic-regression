# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Pranadh\OneDrive\Desktop\tekworks\day20\WA_Fn-UseC_-Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.drop("customerID",axis=1,inplace=True)

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
df['gender'].replace({"Male":1,"Female":0},inplace=True)
df
# Out:
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\1858637742.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace({"Male":1,"Female":0},inplace=True)
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\1858637742.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
df['Partner'].replace({"Yes":1,"No":0},inplace=True)
df
# Out:
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\1724678178.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Partner'].replace({"Yes":1,"No":0},inplace=True)
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\1724678178.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
df['Dependents'].replace({"Yes":1,"No":0},inplace=True)
df
# Out:
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\1874769884.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Dependents'].replace({"Yes":1,"No":0},inplace=True)
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\1874769884.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
df['PhoneService'].replace({"Yes":1,"No":0},inplace=True)
df
# Out:
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\4180620945.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PhoneService'].replace({"Yes":1,"No":0},inplace=True)
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\4180620945.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
df['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
##f['OnlineSecurity'].value_counts()
##df['OnlineBackup'].value_counts()
##df['DeviceProtection'].value_counts()
##df['TechSupport'].value_counts()
# # df['StreamingTV'].value_counts()
# df['StreamingMovies'].value_counts()
df['PaperlessBilling'].value_counts()
# Out:
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64

# %%
df['PaperlessBilling'].replace({"Yes":1,"No":0},inplace=True)
df
# Out:
# C:\Users\Pranadh\AppData\Local\Temp\ipykernel_23556\3758647362.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PaperlessBilling'].replace({"Yes":1,"No":0},inplace=True)
# ...

# %%
df['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
df=pd.get_dummies(df,columns=['Contract','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaymentMethod'])

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges TotalCharges Churn  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   gender                                   7043 non-null   int64
#  1   SeniorCitizen                            7043 non-null   int64
#  2   Partner                                  7043 non-null   int64
#  3   Dependents                               7043 non-null   int64
#  4   tenure                                   7043 non-null   int64
#  5   PhoneService                             7043 non-null   int64
#  6   PaperlessBilling                         7043 non-null   int64
#  7   MonthlyCharges                           7043 non-null   float64
#  8   TotalCharges                             7043 non-null   object
#  9   Churn                                    7043 non-null   object
# ...

# %%
sns.boxplot(df)
plt.figure(figsize=(10,100))
plt.show()

# %%
df['Contract_Month-to-month'].replace({True:1,False:0},inplace=True)
df['Contract_One year'].replace({True:1,False:0},inplace=True)
df['Contract_Two year'].replace({True:1,False:0},inplace=True)
df['MultipleLines_No phone service'].replace({True:1,False:0},inplace=True)
df['MultipleLines_Yes'].replace({True:1,False:0},inplace=True)
df['MultipleLines_No'].replace({True:1,False:0},inplace=True)
df['InternetService_DSL'].replace({True:1,False:0},inplace=True)
df['InternetService_Fiber optic'].replace({True:1,False:0},inplace=True)
df['InternetService_No'].replace({True:1,False:0},inplace=True)
df['OnlineSecurity_No internet service'].replace({True:1,False:0},inplace=True)
df['OnlineSecurity_Yes'].replace({True:1,False:0},inplace=True)
df['OnlineSecurity_No'].replace({True:1,False:0},inplace=True)
df['OnlineBackup_No internet service'].replace({True:1,False:0},inplace=True)
df['OnlineBackup_Yes'].replace({True:1,False:0},inplace=True)
df['OnlineBackup_No'].replace({True:1,False:0},inplace=True)
df['DeviceProtection_No internet service'].replace({True:1,False:0},inplace=True)
df['DeviceProtection_Yes'].replace({True:1,False:0},inplace=True)
df['DeviceProtection_No'].replace({True:1,False:0},inplace=True)
df['TechSupport_No internet service'].replace({True:1,False:0},inplace=True)
df['TechSupport_Yes'].replace({True:1,False:0},inplace=True)
df['TechSupport_No'].replace({True:1,False:0},inplace=True)
df['StreamingTV_No internet service'].replace({True:1,False:0},inplace=True)
df['StreamingTV_Yes'].replace({True:1,False:0},inplace=True)
df['StreamingTV_No'].replace({True:1,False:0},inplace=True)
df['StreamingMovies_No internet service'].replace({True:1,False:0},inplace=True)
df['StreamingMovies_Yes'].replace({True:1,False:0},inplace=True)
df['StreamingMovies_No'].replace({True:1,False:0},inplace=True)
df['PaymentMethod_Bank transfer (automatic)'].replace({True:1,False:0},inplace=True)
df['PaymentMethod_Credit card (automatic)'].replace({True:1,False:0},inplace=True)
df['PaymentMethod_Electronic check'].replace({True:1,False:0},inplace=True)
df['PaymentMethod_Mailed check'].replace({True:1,False:0},inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   gender                                   7043 non-null   int64
#  1   SeniorCitizen                            7043 non-null   int64
#  2   Partner                                  7043 non-null   int64
#  3   Dependents                               7043 non-null   int64
#  4   tenure                                   7043 non-null   int64
#  5   PhoneService                             7043 non-null   int64
#  6   PaperlessBilling                         7043 non-null   int64
#  7   MonthlyCharges                           7043 non-null   float64
#  8   TotalCharges                             7043 non-null   object
#  9   Churn                                    7043 non-null   object
# ...

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'].fillna(df['TotalCharges'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   gender                                   7043 non-null   int64
#  1   SeniorCitizen                            7043 non-null   int64
#  2   Partner                                  7043 non-null   int64
#  3   Dependents                               7043 non-null   int64
#  4   tenure                                   7043 non-null   int64
#  5   PhoneService                             7043 non-null   int64
#  6   PaperlessBilling                         7043 non-null   int64
#  7   MonthlyCharges                           7043 non-null   float64
#  8   TotalCharges                             7043 non-null   float64
#  9   Churn                                    7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# gender                                     0
# SeniorCitizen                              0
# Partner                                    0
# Dependents                                 0
# tenure                                     0
# PhoneService                               0
# PaperlessBilling                           0
# MonthlyCharges                             0
# TotalCharges                               0
# Churn                                      0
# Contract_Month-to-month                    0
# Contract_One year                          0
# Contract_Two year                          0
# MultipleLines_No                           0
# MultipleLines_No phone service             0
# MultipleLines_Yes                          0
# InternetService_DSL                        0
# InternetService_Fiber optic                0
# InternetService_No                         0
# OnlineSecurity_No                          0
# OnlineSecurity_No internet service         0
# ...

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges Churn  ...  \
# ...

# %%
df.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  \
# count   7043.000000       7043.000000     7043.000000   7043.000000
# mean       0.903166          0.592219       64.761692   2283.300441
# std        0.295752          0.491457       30.090047   2265.000258
# ...

# %%
from sklearn.model_selection import train_test_split
x = df.drop("Churn",axis=1)
y = df["Churn"]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression( max_iter=100)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.86      0.90      0.88      1036
#          Yes       0.69      0.61      0.64       373
#
#     accuracy                           0.82      1409
#    macro avg       0.78      0.75      0.76      1409
# weighted avg       0.82      0.82      0.82      1409
#
# [[932 104]
#  [146 227]]
# Accuracy: 0.8225691980127751
# c:\Users\Pranadh\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# ...

# %%
# make a streamlit app
